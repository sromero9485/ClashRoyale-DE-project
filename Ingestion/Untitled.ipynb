# %%
import requests
import json 
from time import sleep, time
from pandas import json_normalize
import pandas as pd

with open("token.txt", "r") as file:
    token = file.read().strip('\n')

base_url = "https://api.clashroyale.com/v1"

headers = {"Authorization": f"Bearer {token}"}

# Archivo donde guardaremos los resultados
output_file = "clanes_data.json"

# Lista de tags de clanes (ejemplo)
clan_tags = ["#L9CRC0PG", "#GG0C0VR0", "#P00CUJ2R", "#LC0GJGRV", "#YVQV2VVY", "#9JUP2U", "#RPQ2QGYC"] 

def get_clan_data(clan_tag):
    endpoint = f"/clans/{clan_tag.replace('#', '%23')}"  # Codificar el # como %23
    url = base_url + endpoint
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        sleep(0.1)  # Pequeña pausa para evitar rate limiting
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error al obtener datos del clan {clan_tag}: {e}")
        return None

def fetch_all_clans_data(tags, output_file):
    start_time = time()  # Iniciar medición de tiempo
    all_data = {}
    total_clans = len(tags)
    
    for i, tag in enumerate(tags, 1):
        print(f"Obteniendo datos del clan {tag} ({i}/{total_clans})...")
        clan_data = get_clan_data(tag)
        
        if clan_data is not None:
            all_data[tag] = clan_data
    
    # Guardar todos los datos
    with open(output_file, "w") as f:
        json.dump(all_data, f, indent=4)
    
    # Calcular tiempo transcurrido
    elapsed_time = time() - start_time
    mins, secs = divmod(elapsed_time, 60)
    
    print(f"\nProceso completado en {int(mins)} minutos y {secs:.2f} segundos")
    print(f"Datos de {len(all_data)}/{total_clans} clanes guardados en {output_file}")
    
    return all_data

# %%
fetch_all_clans_data(clan_tags, output_file)
# Out:
# Obteniendo datos del clan #L9CRC0PG (1/7)...
# Obteniendo datos del clan #GG0C0VR0 (2/7)...
# Obteniendo datos del clan #P00CUJ2R (3/7)...
# Obteniendo datos del clan #LC0GJGRV (4/7)...
# Obteniendo datos del clan #YVQV2VVY (5/7)...
# Obteniendo datos del clan #9JUP2U (6/7)...
# Obteniendo datos del clan #RPQ2QGYC (7/7)...
#
# Proceso completado en 0 minutos y 1.73 segundos
# Datos de 7/7 clanes guardados en clanes_data.json
# {'#L9CRC0PG': {'tag': '#L9CRC0PG',
#   'name': 'Biscy Saucers',
#   'type': 'inviteOnly',
#   'description': '1# Clan in Canada 🇨🇦 Better than the Rest! Very Active and Supportive! Path of Legends Focused 🏆 Full? Join biscy saucers 2!',
#   'badgeId': 16000076,
#   'clanScore': 90000,
#   'clanWarTrophies': 1650,
#   'location': {'id': 57000047,
#    'name': 'Canada',
#    'isCountry': True,
#    'countryCode': 'CA'},
#   'requiredTrophies': 9000,
#   'donationsPerWeek': 2000,
#   'clanChestStatus': 'inactive',
#   'clanChestLevel': 1,
#   'clanChestMaxLevel': 0,
#   'members': 50,
#   'memberList': [{'tag': '#JJU8V9YR',
#     'name': 'BigDanny224',
#     'role': 'coLeader',
#     'lastSeen': '20250529T050542.000Z',
#     'expLevel': 69,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 1,
#     'previousClanRank': 1,
#     'donations': 116,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#C22U88U2',
#     'name': 'Bo$$',
#     'role': 'coLeader',
#     'lastSeen': '20250529T000843.000Z',
#     'expLevel': 69,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 2,
#     'previousClanRank': 2,
#     'donations': 138,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#CG8PURUV0',
#     'name': '弩x-bow弩',
#     'role': 'member',
#     'lastSeen': '20250529T002112.000Z',
#     'expLevel': 58,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 3,
#     'previousClanRank': 3,
#     'donations': 90,
#     'donationsReceived': 320,
#     'clanChestPoints': 0},
#    {'tag': '#PQ2LVJ',
#     'name': 'Zach',
#     'role': 'coLeader',
#     'lastSeen': '20250529T044135.000Z',
#     'expLevel': 65,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 4,
#     'previousClanRank': 4,
#     'donations': 20,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#280PV208J',
#     'name': '<c2>Kyle',
#     'role': 'elder',
#     'lastSeen': '20250529T021932.000Z',
#     'expLevel': 61,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 5,
#     'previousClanRank': 6,
#     'donations': 48,
#     'donationsReceived': 280,
#     'clanChestPoints': 0},
#    {'tag': '#Y8Y0VGJV9',
#     'name': 'da boy',
#     'role': 'elder',
#     'lastSeen': '20250528T233113.000Z',
#     'expLevel': 59,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 6,
#     'previousClanRank': 9,
#     'donations': 88,
#     'donationsReceived': 320,
#     'clanChestPoints': 0},
#    {'tag': '#2YYLYPQRV',
#     'name': 'moopeloo',
#     'role': 'elder',
#     'lastSeen': '20250528T212357.000Z',
#     'expLevel': 62,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 7,
#     'previousClanRank': 7,
#     'donations': 10,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#VPLP99Y09',
#     'name': '<c5>Hamza',
#     'role': 'coLeader',
#     'lastSeen': '20250529T040452.000Z',
#     'expLevel': 68,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 8,
#     'previousClanRank': 5,
#     'donations': 96,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#P9R8RCR9Y',
#     'name': 'Tysen',
#     'role': 'member',
#     'lastSeen': '20250528T190029.000Z',
#     'expLevel': 59,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 9,
#     'previousClanRank': 8,
#     'donations': 8,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#PY08QGUQ0',
#     'name': 'PwayBoyCarti',
#     'role': 'member',
#     'lastSeen': '20250528T184319.000Z',
#     'expLevel': 64,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 10,
#     'previousClanRank': 13,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#RUPQPUJU',
#     'name': 'andrew',
#     'role': 'coLeader',
#     'lastSeen': '20250528T175827.000Z',
#     'expLevel': 65,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 11,
#     'previousClanRank': 10,
#     'donations': 20,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#VLYRJYLPU',
#     'name': 'andrew2',
#     'role': 'coLeader',
#     'lastSeen': '20250528T203057.000Z',
#     'expLevel': 61,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 12,
#     'previousClanRank': 11,
#     'donations': 18,
#     'donationsReceived': 120,
#     'clanChestPoints': 0},
#    {'tag': '#8VQRCQYGY',
#     'name': 'Panagioti',
#     'role': 'member',
#     'lastSeen': '20250529T053337.000Z',
#     'expLevel': 65,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 13,
#     'previousClanRank': 16,
#     'donations': 122,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#LP9GPQUU',
#     'name': 'harpreet',
#     'role': 'elder',
#     'lastSeen': '20250529T012943.000Z',
#     'expLevel': 60,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 14,
#     'previousClanRank': 19,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#V80Y280Y2',
#     'name': 'ка4ок сунду4ок',
#     'role': 'member',
#     'lastSeen': '20250528T195234.000Z',
#     'expLevel': 60,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 15,
#     'previousClanRank': 15,
#     'donations': 36,
#     'donationsReceived': 280,
#     'clanChestPoints': 0},
#    {'tag': '#2QR2VYVL',
#     'name': 'X-King Kong-X',
#     'role': 'elder',
#     'lastSeen': '20250528T190106.000Z',
#     'expLevel': 68,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 16,
#     'previousClanRank': 18,
#     'donations': 28,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#GCL02',
#     'name': 'Smaash',
#     'role': 'member',
#     'lastSeen': '20250528T230140.000Z',
#     'expLevel': 64,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 17,
#     'previousClanRank': 17,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#8UPY8CJ',
#     'name': 'pizzo',
#     'role': 'member',
#     'lastSeen': '20250529T030710.000Z',
#     'expLevel': 62,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 18,
#     'previousClanRank': 32,
#     'donations': 40,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#8QRU2RRQL',
#     'name': 'Adi',
#     'role': 'elder',
#     'lastSeen': '20250529T040822.000Z',
#     'expLevel': 64,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 19,
#     'previousClanRank': 22,
#     'donations': 48,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#CR9P9YJG',
#     'name': 'すBon Kし',
#     'role': 'member',
#     'lastSeen': '20250529T044435.000Z',
#     'expLevel': 64,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 20,
#     'previousClanRank': 12,
#     'donations': 46,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#UCQ9GGPP',
#     'name': 'JELK',
#     'role': 'member',
#     'lastSeen': '20250529T020426.000Z',
#     'expLevel': 65,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 21,
#     'previousClanRank': 35,
#     'donations': 114,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#YL0CVCV',
#     'name': '<c5>Will',
#     'role': 'member',
#     'lastSeen': '20250529T025916.000Z',
#     'expLevel': 70,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 22,
#     'previousClanRank': 21,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#2UL9QPUQC',
#     'name': 'Top G',
#     'role': 'member',
#     'lastSeen': '20250528T220347.000Z',
#     'expLevel': 63,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 23,
#     'previousClanRank': 39,
#     'donations': 36,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#JGGLVVL',
#     'name': 'DFlem',
#     'role': 'member',
#     'lastSeen': '20250529T015712.000Z',
#     'expLevel': 58,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 24,
#     'previousClanRank': 26,
#     'donations': 38,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#UVJCVR2V',
#     'name': 'grandaddy kush',
#     'role': 'elder',
#     'lastSeen': '20250528T223537.000Z',
#     'expLevel': 65,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 25,
#     'previousClanRank': 40,
#     'donations': 20,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#JL02JRGG',
#     'name': 'cheese by bob',
#     'role': 'elder',
#     'lastSeen': '20250529T044609.000Z',
#     'expLevel': 62,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 26,
#     'previousClanRank': 23,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#2PJRPLV9',
#     'name': 'KA B00M',
#     'role': 'member',
#     'lastSeen': '20250528T222624.000Z',
#     'expLevel': 59,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 27,
#     'previousClanRank': 20,
#     'donations': 28,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#2Q0RJL9JY',
#     'name': 'joe',
#     'role': 'elder',
#     'lastSeen': '20250529T060857.000Z',
#     'expLevel': 65,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 28,
#     'previousClanRank': 14,
#     'donations': 132,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#Q2Y9C8QYJ',
#     'name': 'Inspirational D',
#     'role': 'elder',
#     'lastSeen': '20250528T065610.000Z',
#     'expLevel': 68,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 29,
#     'previousClanRank': 24,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#PVJYGYL',
#     'name': 'newB',
#     'role': 'member',
#     'lastSeen': '20250529T001515.000Z',
#     'expLevel': 62,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 30,
#     'previousClanRank': 25,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#CC2LPLYUV',
#     'name': 'HugeHorn',
#     'role': 'member',
#     'lastSeen': '20250529T024143.000Z',
#     'expLevel': 61,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 31,
#     'previousClanRank': 27,
#     'donations': 58,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#P000QCJ',
#     'name': '<c6>Snoop',
#     'role': 'elder',
#     'lastSeen': '20250528T142632.000Z',
#     'expLevel': 68,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 32,
#     'previousClanRank': 31,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#YJPUYQ8',
#     'name': 'ruthless',
#     'role': 'coLeader',
#     'lastSeen': '20250528T184002.000Z',
#     'expLevel': 68,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 33,
#     'previousClanRank': 34,
#     'donations': 48,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#QVL8LRRJL',
#     'name': 'GrimReaper123',
#     'role': 'member',
#     'lastSeen': '20250529T043251.000Z',
#     'expLevel': 57,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 34,
#     'previousClanRank': 30,
#     'donations': 8,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#L0U992J8',
#     'name': '<c5>ME',
#     'role': 'elder',
#     'lastSeen': '20250529T044229.000Z',
#     'expLevel': 60,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 35,
#     'previousClanRank': 29,
#     'donations': 118,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#C9ULQ9U',
#     'name': 'Kev91',
#     'role': 'member',
#     'lastSeen': '20250529T014949.000Z',
#     'expLevel': 56,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 36,
#     'previousClanRank': 28,
#     'donations': 20,
#     'donationsReceived': 40,
#     'clanChestPoints': 0},
#    {'tag': '#QR0V9VJ',
#     'name': 'ThatOneGuy',
#     'role': 'member',
#     'lastSeen': '20250529T045700.000Z',
#     'expLevel': 59,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 37,
#     'previousClanRank': 33,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#9JRJV89JQ',
#     'name': 'Emmett',
#     'role': 'member',
#     'lastSeen': '20250529T033150.000Z',
#     'expLevel': 59,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 38,
#     'previousClanRank': 36,
#     'donations': 8,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#8QUYQ0CPU',
#     'name': 'Dark Light',
#     'role': 'member',
#     'lastSeen': '20250529T053220.000Z',
#     'expLevel': 70,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 39,
#     'previousClanRank': 45,
#     'donations': 30,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#QQYY2VQQ',
#     'name': 'BRETT',
#     'role': 'member',
#     'lastSeen': '20250529T042330.000Z',
#     'expLevel': 56,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 40,
#     'previousClanRank': 42,
#     'donations': 98,
#     'donationsReceived': 240,
#     'clanChestPoints': 0},
#    {'tag': '#YLJL0JP',
#     'name': 'Lui',
#     'role': 'elder',
#     'lastSeen': '20250529T040144.000Z',
#     'expLevel': 65,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 41,
#     'previousClanRank': 38,
#     'donations': 90,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#RGRL0VG2V',
#     'name': 'Squidlips',
#     'role': 'leader',
#     'lastSeen': '20250529T011019.000Z',
#     'expLevel': 69,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 42,
#     'previousClanRank': 41,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#8J9C8QRC',
#     'name': 'soy sauce',
#     'role': 'member',
#     'lastSeen': '20250529T003205.000Z',
#     'expLevel': 59,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 43,
#     'previousClanRank': 44,
#     'donations': 0,
#     'donationsReceived': 200,
#     'clanChestPoints': 0},
#    {'tag': '#2QU2QV9V',
#     'name': 'mekanic',
#     'role': 'member',
#     'lastSeen': '20250529T001332.000Z',
#     'expLevel': 70,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 44,
#     'previousClanRank': 46,
#     'donations': 106,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#PJCRL0YY0',
#     'name': 'pinky',
#     'role': 'elder',
#     'lastSeen': '20250528T211854.000Z',
#     'expLevel': 56,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 45,
#     'previousClanRank': 48,
#     'donations': 10,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#2Y090RPG',
#     'name': 'Luffy214',
#     'role': 'member',
#     'lastSeen': '20250528T190806.000Z',
#     'expLevel': 60,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 46,
#     'previousClanRank': 47,
#     'donations': 36,
#     'donationsReceived': 200,
#     'clanChestPoints': 0},
#    {'tag': '#8G2C0C0U',
#     'name': 'royale king',
#     'role': 'member',
#     'lastSeen': '20250528T183904.000Z',
#     'expLevel': 60,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 47,
#     'previousClanRank': 50,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#Y20UC9YGR',
#     'name': 'PRDGY_Zachy',
#     'role': 'member',
#     'lastSeen': '20250528T183834.000Z',
#     'expLevel': 58,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 48,
#     'previousClanRank': 43,
#     'donations': 20,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#VQCPULVP',
#     'name': 'KIRITO',
#     'role': 'member',
#     'lastSeen': '20250528T162737.000Z',
#     'expLevel': 63,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 49,
#     'previousClanRank': 37,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#LLG0Q9P0',
#     'name': 'TurtleVu',
#     'role': 'member',
#     'lastSeen': '20250528T104507.000Z',
#     'expLevel': 57,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 50,
#     'previousClanRank': 49,
#     'donations': 10,
#     'donationsReceived': 0,
#     'clanChestPoints': 0}]},
#  '#GG0C0VR0': {'tag': '#GG0C0VR0',
#   'name': 'Jynxzi Verse',
#   'type': 'inviteOnly',
#   'description': '',
#   'badgeId': 16000008,
#   'clanScore': 90000,
#   'clanWarTrophies': 180,
#   'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#   'requiredTrophies': 9000,
#   'donationsPerWeek': 3944,
#   'clanChestStatus': 'inactive',
#   'clanChestLevel': 1,
#   'clanChestMaxLevel': 0,
#   'members': 50,
#   'memberList': [{'tag': '#YJPLQRR09',
#     'name': 'Lil Log',
#     'role': 'coLeader',
#     'lastSeen': '20250528T175022.000Z',
#     'expLevel': 59,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 1,
#     'previousClanRank': 1,
#     'donations': 0,
#     'donationsReceived': 80,
#     'clanChestPoints': 0},
#    {'tag': '#V280LRLC',
#     'name': 'The Fishinator',
#     'role': 'member',
#     'lastSeen': '20250529T060756.000Z',
#     'expLevel': 70,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 2,
#     'previousClanRank': 2,
#     'donations': 24,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#LGYY8JYV',
#     'name': 'CHN｜Taker',
#     'role': 'member',
#     'lastSeen': '20250529T060904.000Z',
#     'expLevel': 64,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 3,
#     'previousClanRank': 5,
#     'donations': 166,
#     'donationsReceived': 200,
#     'clanChestPoints': 0},
#    {'tag': '#R0CL8LPCL',
#     'name': 'CODE: Innvader',
#     'role': 'member',
#     'lastSeen': '20250529T054235.000Z',
#     'expLevel': 66,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 4,
#     'previousClanRank': 6,
#     'donations': 36,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#298LLPGQP',
#     'name': 'BLADE',
#     'role': 'member',
#     'lastSeen': '20250529T060601.000Z',
#     'expLevel': 69,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 5,
#     'previousClanRank': 3,
#     'donations': 160,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#LGYPLRPLR',
#     'name': 'deen',
#     'role': 'elder',
#     'lastSeen': '20250529T031919.000Z',
#     'expLevel': 70,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 6,
#     'previousClanRank': 8,
#     'donations': 36,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#J9VJPVRL',
#     'name': 'Dr.HELLCAT⚡️mig',
#     'role': 'member',
#     'lastSeen': '20250529T051109.000Z',
#     'expLevel': 66,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 7,
#     'previousClanRank': 7,
#     'donations': 8,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#PULJYQYQ',
#     'name': 'Keppa',
#     'role': 'elder',
#     'lastSeen': '20250529T042351.000Z',
#     'expLevel': 60,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 8,
#     'previousClanRank': 9,
#     'donations': 160,
#     'donationsReceived': 40,
#     'clanChestPoints': 0},
#    {'tag': '#PYP2CP2Q9',
#     'name': 'Rylan™️',
#     'role': 'member',
#     'lastSeen': '20250529T050358.000Z',
#     'expLevel': 63,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 9,
#     'previousClanRank': 11,
#     'donations': 70,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#8GGY0L2U2',
#     'name': '0pag',
#     'role': 'member',
#     'lastSeen': '20250529T053629.000Z',
#     'expLevel': 70,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 10,
#     'previousClanRank': 22,
#     'donations': 120,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#R2CVG09Y',
#     'name': 'Jelle',
#     'role': 'member',
#     'lastSeen': '20250528T125226.000Z',
#     'expLevel': 62,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 11,
#     'previousClanRank': 10,
#     'donations': 58,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#2UPRPQV2G',
#     'name': 'Choo',
#     'role': 'member',
#     'lastSeen': '20250528T220905.000Z',
#     'expLevel': 70,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 12,
#     'previousClanRank': 17,
#     'donations': 50,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#Y2UQCUQ',
#     'name': 'Xerxes',
#     'role': 'member',
#     'lastSeen': '20250529T040136.000Z',
#     'expLevel': 64,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 13,
#     'previousClanRank': 14,
#     'donations': 120,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#2QY0RLQ9G',
#     'name': '齲区ＩEric《ゞ》',
#     'role': 'member',
#     'lastSeen': '20250529T050815.000Z',
#     'expLevel': 67,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 14,
#     'previousClanRank': 0,
#     'donations': 18,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#YR2YYPCLY',
#     'name': '<c4>Anish',
#     'role': 'member',
#     'lastSeen': '20250529T042521.000Z',
#     'expLevel': 62,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 15,
#     'previousClanRank': 0,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#PJCJQ82',
#     'name': 'Owen',
#     'role': 'member',
#     'lastSeen': '20250528T050622.000Z',
#     'expLevel': 65,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 16,
#     'previousClanRank': 13,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#RV8R0RJ9C',
#     'name': 'Nemo',
#     'role': 'member',
#     'lastSeen': '20250529T021938.000Z',
#     'expLevel': 56,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 17,
#     'previousClanRank': 16,
#     'donations': 166,
#     'donationsReceived': 360,
#     'clanChestPoints': 0},
#    {'tag': '#QPJCJCJY',
#     'name': '神nicto✨',
#     'role': 'member',
#     'lastSeen': '20250529T014327.000Z',
#     'expLevel': 67,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 18,
#     'previousClanRank': 18,
#     'donations': 26,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#80YQJJQGQ',
#     'name': 'Cristo',
#     'role': 'member',
#     'lastSeen': '20250528T232758.000Z',
#     'expLevel': 66,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 19,
#     'previousClanRank': 15,
#     'donations': 16,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#PRLGCJGC',
#     'name': 'CODE Jynxzi',
#     'role': 'leader',
#     'lastSeen': '20250529T055814.000Z',
#     'expLevel': 60,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 20,
#     'previousClanRank': 19,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#RQVJUY8UQ',
#     'name': '<c6> faith',
#     'role': 'member',
#     'lastSeen': '20250529T050055.000Z',
#     'expLevel': 62,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 21,
#     'previousClanRank': 21,
#     'donations': 26,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#98YJC2QV',
#     'name': 'Wink1080',
#     'role': 'member',
#     'lastSeen': '20250529T044741.000Z',
#     'expLevel': 64,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 22,
#     'previousClanRank': 33,
#     'donations': 94,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#PULQRQY00',
#     'name': 'Alex_CR',
#     'role': 'member',
#     'lastSeen': '20250528T222928.000Z',
#     'expLevel': 59,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 23,
#     'previousClanRank': 23,
#     'donations': 106,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#PGP2RCJJ',
#     'name': 'Yadeine',
#     'role': 'elder',
#     'lastSeen': '20250529T044248.000Z',
#     'expLevel': 59,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 24,
#     'previousClanRank': 28,
#     'donations': 86,
#     'donationsReceived': 280,
#     'clanChestPoints': 0},
#    {'tag': '#PV09CUJ2C',
#     'name': 'Mäśñ❤️ÑøŠkîll',
#     'role': 'member',
#     'lastSeen': '20250529T040217.000Z',
#     'expLevel': 62,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 25,
#     'previousClanRank': 20,
#     'donations': 103,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#2Q8RR080G',
#     'name': 'Eman',
#     'role': 'member',
#     'lastSeen': '20250529T033313.000Z',
#     'expLevel': 69,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 26,
#     'previousClanRank': 24,
#     'donations': 226,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#8PRYGV99',
#     'name': 'Sfidante',
#     'role': 'member',
#     'lastSeen': '20250528T192239.000Z',
#     'expLevel': 59,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 27,
#     'previousClanRank': 29,
#     'donations': 78,
#     'donationsReceived': 240,
#     'clanChestPoints': 0},
#    {'tag': '#Y9VJ8C0P',
#     'name': 'Highscore.',
#     'role': 'elder',
#     'lastSeen': '20250529T060044.000Z',
#     'expLevel': 67,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 28,
#     'previousClanRank': 30,
#     'donations': 412,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#J8PYQJ0',
#     'name': 'Zain',
#     'role': 'member',
#     'lastSeen': '20250529T044151.000Z',
#     'expLevel': 56,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 29,
#     'previousClanRank': 31,
#     'donations': 50,
#     'donationsReceived': 240,
#     'clanChestPoints': 0},
#    {'tag': '#YVR0JGQJ0',
#     'name': 'Dogtown',
#     'role': 'member',
#     'lastSeen': '20250529T032431.000Z',
#     'expLevel': 56,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 30,
#     'previousClanRank': 34,
#     'donations': 42,
#     'donationsReceived': 280,
#     'clanChestPoints': 0},
#    {'tag': '#8VQV88Y0J',
#     'name': 'SlowFeet',
#     'role': 'elder',
#     'lastSeen': '20250529T053742.000Z',
#     'expLevel': 56,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 31,
#     'previousClanRank': 35,
#     'donations': 122,
#     'donationsReceived': 360,
#     'clanChestPoints': 0},
#    {'tag': '#8Y9YGP0G',
#     'name': 'Shade',
#     'role': 'member',
#     'lastSeen': '20250528T195148.000Z',
#     'expLevel': 56,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 32,
#     'previousClanRank': 26,
#     'donations': 7,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#YCQUVGG8',
#     'name': 'beast',
#     'role': 'member',
#     'lastSeen': '20250528T205113.000Z',
#     'expLevel': 60,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 33,
#     'previousClanRank': 41,
#     'donations': 40,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#2G8R0G2J',
#     'name': 'Dynamic⚡',
#     'role': 'member',
#     'lastSeen': '20250528T235923.000Z',
#     'expLevel': 53,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 34,
#     'previousClanRank': 38,
#     'donations': 77,
#     'donationsReceived': 240,
#     'clanChestPoints': 0},
#    {'tag': '#88R9PPP20',
#     'name': 'ifnmx',
#     'role': 'member',
#     'lastSeen': '20250529T055901.000Z',
#     'expLevel': 62,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 35,
#     'previousClanRank': 39,
#     'donations': 50,
#     'donationsReceived': 360,
#     'clanChestPoints': 0},
#    {'tag': '#UV28QGCQ',
#     'name': 'anti',
#     'role': 'member',
#     'lastSeen': '20250528T164252.000Z',
#     'expLevel': 59,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 36,
#     'previousClanRank': 40,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#9Y0CJYCG',
#     'name': 'miner?',
#     'role': 'member',
#     'lastSeen': '20250529T033837.000Z',
#     'expLevel': 67,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 37,
#     'previousClanRank': 45,
#     'donations': 101,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#PQV9GPVLL',
#     'name': 'Comatose',
#     'role': 'member',
#     'lastSeen': '20250529T023649.000Z',
#     'expLevel': 70,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 38,
#     'previousClanRank': 43,
#     'donations': 50,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#8P9288JLL',
#     'name': 'Jon',
#     'role': 'member',
#     'lastSeen': '20250528T224004.000Z',
#     'expLevel': 60,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 39,
#     'previousClanRank': 36,
#     'donations': 58,
#     'donationsReceived': 40,
#     'clanChestPoints': 0},
#    {'tag': '#Y2YC009U',
#     'name': 'Wolly Greenwood',
#     'role': 'member',
#     'lastSeen': '20250529T054044.000Z',
#     'expLevel': 60,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 40,
#     'previousClanRank': 27,
#     'donations': 100,
#     'donationsReceived': 280,
#     'clanChestPoints': 0},
#    {'tag': '#89P8LLYG8',
#     'name': 'ＥＺ✨ＲＡＮＤＯＭ',
#     'role': 'member',
#     'lastSeen': '20250529T052152.000Z',
#     'expLevel': 59,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 41,
#     'previousClanRank': 25,
#     'donations': 153,
#     'donationsReceived': 360,
#     'clanChestPoints': 0},
#    {'tag': '#RY9GCU99',
#     'name': 'B R O O K S',
#     'role': 'member',
#     'lastSeen': '20250529T015707.000Z',
#     'expLevel': 61,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 42,
#     'previousClanRank': 37,
#     'donations': 114,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#2UCLCPVC9',
#     'name': '_SuChRoD_',
#     'role': 'member',
#     'lastSeen': '20250528T214521.000Z',
#     'expLevel': 58,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 43,
#     'previousClanRank': 44,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#QCJ8YG99',
#     'name': 'Trainer MikeO_o',
#     'role': 'member',
#     'lastSeen': '20250529T043543.000Z',
#     'expLevel': 62,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 44,
#     'previousClanRank': 47,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#L9YJ2RJRL',
#     'name': 'Ethen',
#     'role': 'member',
#     'lastSeen': '20250529T044246.000Z',
#     'expLevel': 57,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 45,
#     'previousClanRank': 46,
#     'donations': 24,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#PP09JPV08',
#     'name': 'I luv shyaam',
#     'role': 'member',
#     'lastSeen': '20250529T040710.000Z',
#     'expLevel': 55,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 46,
#     'previousClanRank': 42,
#     'donations': 153,
#     'donationsReceived': 400,
#     'clanChestPoints': 0},
#    {'tag': '#Y8G8QYRG2',
#     'name': 'Gingox',
#     'role': 'member',
#     'lastSeen': '20250529T032755.000Z',
#     'expLevel': 54,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 47,
#     'previousClanRank': 49,
#     'donations': 26,
#     'donationsReceived': 40,
#     'clanChestPoints': 0},
#    {'tag': '#2RLL8V2CQ',
#     'name': '<c2>JBoss',
#     'role': 'elder',
#     'lastSeen': '20250529T053254.000Z',
#     'expLevel': 68,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 48,
#     'previousClanRank': 32,
#     'donations': 225,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#2G8CLLVYY',
#     'name': 'Mike Glenon',
#     'role': 'member',
#     'lastSeen': '20250529T030820.000Z',
#     'expLevel': 58,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 49,
#     'previousClanRank': 50,
#     'donations': 63,
#     'donationsReceived': 40,
#     'clanChestPoints': 0},
#    {'tag': '#C9QC2Q2YY',
#     'name': '<c2>㌨☽',
#     'role': 'member',
#     'lastSeen': '20250529T035329.000Z',
#     'expLevel': 59,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 50,
#     'previousClanRank': 48,
#     'donations': 39,
#     'donationsReceived': 0,
#     'clanChestPoints': 0}]},
#  '#P00CUJ2R': {'tag': '#P00CUJ2R',
#   'name': 'Eternal Imperio',
#   'type': 'open',
#   'description': '🔱Bienvenidos a la familia Eternal🔱 ⚜️Una nueva Era comienza⚜️ Gente activa⚜️ Donaciones y Guerras⚜️. ⚜️clan veterano 8 años⚜️',
#   'badgeId': 16000013,
#   'clanScore': 90000,
#   'clanWarTrophies': 2300,
#   'location': {'id': 57000181,
#    'name': 'Panama',
#    'isCountry': True,
#    'countryCode': 'PA'},
#   'requiredTrophies': 9000,
#   'donationsPerWeek': 1500,
#   'clanChestStatus': 'inactive',
#   'clanChestLevel': 1,
#   'clanChestMaxLevel': 0,
#   'members': 50,
#   'memberList': [{'tag': '#20Y8GVRLQ',
#     'name': 'david liu',
#     'role': 'member',
#     'lastSeen': '20250529T024336.000Z',
#     'expLevel': 66,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 1,
#     'previousClanRank': 1,
#     'donations': 91,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#PGJPPLUL',
#     'name': 'Eternal™Alexis⚡',
#     'role': 'coLeader',
#     'lastSeen': '20250528T175042.000Z',
#     'expLevel': 58,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 2,
#     'previousClanRank': 42,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#PQPCJ02RC',
#     'name': 'BCㅤBϟZZ么R亗',
#     'role': 'member',
#     'lastSeen': '20250529T011530.000Z',
#     'expLevel': 62,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 3,
#     'previousClanRank': 3,
#     'donations': 62,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#2VQVGJC',
#     'name': 'ＡＬＥＸＩＳ⁵⁰⁷',
#     'role': 'member',
#     'lastSeen': '20250529T015514.000Z',
#     'expLevel': 61,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 4,
#     'previousClanRank': 6,
#     'donations': 60,
#     'donationsReceived': 160,
#     'clanChestPoints': 0},
#    {'tag': '#2YLQLR0PL',
#     'name': 'JosuéAarón',
#     'role': 'member',
#     'lastSeen': '20250528T195832.000Z',
#     'expLevel': 67,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 5,
#     'previousClanRank': 2,
#     'donations': 68,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#LCRR2U0R',
#     'name': 'Eternal ™⭐EDI⭐',
#     'role': 'leader',
#     'lastSeen': '20250528T193015.000Z',
#     'expLevel': 62,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 6,
#     'previousClanRank': 5,
#     'donations': 80,
#     'donationsReceived': 160,
#     'clanChestPoints': 0},
#    {'tag': '#8U280QUP',
#     'name': 'KristonitoPTY',
#     'role': 'member',
#     'lastSeen': '20250528T233655.000Z',
#     'expLevel': 67,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 7,
#     'previousClanRank': 4,
#     'donations': 98,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#YQCGRGYV8',
#     'name': 'ANDROIDE 10.',
#     'role': 'member',
#     'lastSeen': '20250529T023146.000Z',
#     'expLevel': 63,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 8,
#     'previousClanRank': 8,
#     'donations': 55,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#8GPY0RL2',
#     'name': 'Deva',
#     'role': 'member',
#     'lastSeen': '20250528T184917.000Z',
#     'expLevel': 61,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 9,
#     'previousClanRank': 7,
#     'donations': 28,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#92QQUR0GC',
#     'name': 'weboloko',
#     'role': 'elder',
#     'lastSeen': '20250529T035924.000Z',
#     'expLevel': 62,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 10,
#     'previousClanRank': 9,
#     'donations': 16,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#LY8Y0R929',
#     'name': 'SHIRO.YT',
#     'role': 'member',
#     'lastSeen': '20250529T060724.000Z',
#     'expLevel': 57,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 11,
#     'previousClanRank': 26,
#     'donations': 30,
#     'donationsReceived': 280,
#     'clanChestPoints': 0},
#    {'tag': '#UY0QUYCCV',
#     'name': 'edgar28',
#     'role': 'member',
#     'lastSeen': '20250529T054456.000Z',
#     'expLevel': 52,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 12,
#     'previousClanRank': 39,
#     'donations': 0,
#     'donationsReceived': 80,
#     'clanChestPoints': 0},
#    {'tag': '#2QUP88PP',
#     'name': 'ErickAntonio',
#     'role': 'member',
#     'lastSeen': '20250529T053305.000Z',
#     'expLevel': 57,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 13,
#     'previousClanRank': 40,
#     'donations': 8,
#     'donationsReceived': 140,
#     'clanChestPoints': 0},
#    {'tag': '#Q8C9G8J9G',
#     'name': 'ELREY',
#     'role': 'member',
#     'lastSeen': '20250529T052449.000Z',
#     'expLevel': 64,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 14,
#     'previousClanRank': 37,
#     'donations': 80,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#8U0U0R9',
#     'name': '《Zhec》◇',
#     'role': 'member',
#     'lastSeen': '20250529T050056.000Z',
#     'expLevel': 61,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 15,
#     'previousClanRank': 19,
#     'donations': 36,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#CGVUQC2J',
#     'name': 'CABALLERO XD',
#     'role': 'member',
#     'lastSeen': '20250529T043922.000Z',
#     'expLevel': 63,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 16,
#     'previousClanRank': 33,
#     'donations': 24,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#JCJ9YLG',
#     'name': 'Hysteria™',
#     'role': 'member',
#     'lastSeen': '20250529T043551.000Z',
#     'expLevel': 60,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 17,
#     'previousClanRank': 41,
#     'donations': 8,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#PR2QGYU0L',
#     'name': 'Karti',
#     'role': 'member',
#     'lastSeen': '20250529T024029.000Z',
#     'expLevel': 65,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 18,
#     'previousClanRank': 31,
#     'donations': 8,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#JRYJ0UCRU',
#     'name': 'bp',
#     'role': 'member',
#     'lastSeen': '20250529T022502.000Z',
#     'expLevel': 56,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 19,
#     'previousClanRank': 13,
#     'donations': 16,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#80YRCLR8Y',
#     'name': 'Joss竜神ツ',
#     'role': 'coLeader',
#     'lastSeen': '20250529T022038.000Z',
#     'expLevel': 56,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 20,
#     'previousClanRank': 38,
#     'donations': 0,
#     'donationsReceived': 160,
#     'clanChestPoints': 0},
#    {'tag': '#CYJY20R9',
#     'name': 'Major Soto',
#     'role': 'member',
#     'lastSeen': '20250529T021642.000Z',
#     'expLevel': 66,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 21,
#     'previousClanRank': 21,
#     'donations': 64,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#80J8UYPR0',
#     'name': 'Aleoz.',
#     'role': 'member',
#     'lastSeen': '20250529T021238.000Z',
#     'expLevel': 55,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 22,
#     'previousClanRank': 36,
#     'donations': 108,
#     'donationsReceived': 200,
#     'clanChestPoints': 0},
#    {'tag': '#PG0CRU8U0',
#     'name': '"(RON)"',
#     'role': 'member',
#     'lastSeen': '20250529T020224.000Z',
#     'expLevel': 64,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 23,
#     'previousClanRank': 28,
#     'donations': 140,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#QQU0CVGG8',
#     'name': "'.'Maykol²³",
#     'role': 'member',
#     'lastSeen': '20250529T015314.000Z',
#     'expLevel': 59,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 24,
#     'previousClanRank': 11,
#     'donations': 36,
#     'donationsReceived': 120,
#     'clanChestPoints': 0},
#    {'tag': '#8Y2RCLVJC',
#     'name': 'matalo_jeyson',
#     'role': 'member',
#     'lastSeen': '20250529T013809.000Z',
#     'expLevel': 57,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 25,
#     'previousClanRank': 18,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#9QPJPLL0',
#     'name': 'Toby_Empire507',
#     'role': 'member',
#     'lastSeen': '20250529T013207.000Z',
#     'expLevel': 56,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 26,
#     'previousClanRank': 27,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#LLRP0JVP0',
#     'name': 'MOSTRO',
#     'role': 'member',
#     'lastSeen': '20250529T003756.000Z',
#     'expLevel': 62,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 27,
#     'previousClanRank': 24,
#     'donations': 67,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#8VYY888P',
#     'name': 'KAI',
#     'role': 'coLeader',
#     'lastSeen': '20250529T003452.000Z',
#     'expLevel': 64,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 28,
#     'previousClanRank': 34,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#9RP0RJ8YR',
#     'name': 'QU/JTH25',
#     'role': 'member',
#     'lastSeen': '20250528T235627.000Z',
#     'expLevel': 65,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 29,
#     'previousClanRank': 14,
#     'donations': 50,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#20LPYUY9',
#     'name': 'Maestro leonel',
#     'role': 'member',
#     'lastSeen': '20250528T232233.000Z',
#     'expLevel': 57,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 30,
#     'previousClanRank': 20,
#     'donations': 0,
#     'donationsReceived': 40,
#     'clanChestPoints': 0},
#    {'tag': '#LCP0Q220',
#     'name': 'k nalla',
#     'role': 'elder',
#     'lastSeen': '20250528T230609.000Z',
#     'expLevel': 65,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 31,
#     'previousClanRank': 29,
#     'donations': 25,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#JVY9QL2',
#     'name': 'WILDER KING',
#     'role': 'member',
#     'lastSeen': '20250528T230256.000Z',
#     'expLevel': 60,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 32,
#     'previousClanRank': 47,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#LY0QQ89L2',
#     'name': 'GARU 3/20',
#     'role': 'member',
#     'lastSeen': '20250528T225345.000Z',
#     'expLevel': 61,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 33,
#     'previousClanRank': 45,
#     'donations': 8,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#GP8UQ9UYU',
#     'name': 'TK⚡Yahir⚡26',
#     'role': 'member',
#     'lastSeen': '20250528T214057.000Z',
#     'expLevel': 55,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 34,
#     'previousClanRank': 48,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#98Q8GVQG9',
#     'name': 'nirvarub',
#     'role': 'member',
#     'lastSeen': '20250528T213753.000Z',
#     'expLevel': 61,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 35,
#     'previousClanRank': 35,
#     'donations': 10,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#9PGRQJRVV',
#     'name': 'HT',
#     'role': 'coLeader',
#     'lastSeen': '20250528T210734.000Z',
#     'expLevel': 64,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 36,
#     'previousClanRank': 15,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#2GRVU8LVQ',
#     'name': 'nico el pro',
#     'role': 'member',
#     'lastSeen': '20250528T205245.000Z',
#     'expLevel': 57,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 37,
#     'previousClanRank': 17,
#     'donations': 28,
#     'donationsReceived': 80,
#     'clanChestPoints': 0},
#    {'tag': '#YP9GQCLGY',
#     'name': 'OWESITO!¹⁶',
#     'role': 'member',
#     'lastSeen': '20250528T194148.000Z',
#     'expLevel': 59,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 38,
#     'previousClanRank': 50,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#URQ8U89',
#     'name': 'Alex23',
#     'role': 'member',
#     'lastSeen': '20250528T185821.000Z',
#     'expLevel': 63,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 39,
#     'previousClanRank': 16,
#     'donations': 85,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#L9LL280PJ',
#     'name': 'DARIO507',
#     'role': 'elder',
#     'lastSeen': '20250528T183027.000Z',
#     'expLevel': 58,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 40,
#     'previousClanRank': 44,
#     'donations': 16,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#2QJQJVGG',
#     'name': 'yosoymatheo',
#     'role': 'elder',
#     'lastSeen': '20250528T172559.000Z',
#     'expLevel': 68,
#     'trophies': 9000,
# ...
#     'expLevel': 30,
#     'trophies': 3800,
#     'arena': {'id': 54000011, 'name': 'Spooky Town'},
#     'clanRank': 44,
#     'previousClanRank': 44,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#UL0CVQ9QJ',
#     'name': 'ZICVIDY',
#     'role': 'member',
#     'lastSeen': '20250528T141846.000Z',
#     'expLevel': 22,
#     'trophies': 2769,
#     'arena': {'id': 54000010, 'name': 'Jungle Arena'},
#     'clanRank': 45,
#     'previousClanRank': 45,
#     'donations': 1,
#     'donationsReceived': 30,
#     'clanChestPoints': 0},
#    {'tag': '#20YU8R0YRC',
#     'name': 'ľitaliano',
#     'role': 'member',
#     'lastSeen': '20250527T130114.000Z',
#     'expLevel': 22,
#     'trophies': 2636,
#     'arena': {'id': 54000010, 'name': 'Jungle Arena'},
#     'clanRank': 46,
#     'previousClanRank': 46,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#VCUYLJPCP',
#     'name': '868',
#     'role': 'member',
#     'lastSeen': '20250528T021224.000Z',
#     'expLevel': 19,
#     'trophies': 2443,
#     'arena': {'id': 54000009, 'name': 'Frozen Peak'},
#     'clanRank': 47,
#     'previousClanRank': 47,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#UL009L2VG',
#     'name': 'chucho :)',
#     'role': 'member',
#     'lastSeen': '20250529T030148.000Z',
#     'expLevel': 14,
#     'trophies': 2184,
#     'arena': {'id': 54000008, 'name': 'Royal Arena'},
#     'clanRank': 48,
#     'previousClanRank': 48,
#     'donations': 20,
#     'donationsReceived': 80,
#     'clanChestPoints': 0},
#    {'tag': '#UULVY0QR0',
#     'name': 'MINI PEKA',
#     'role': 'member',
#     'lastSeen': '20250528T132700.000Z',
#     'expLevel': 13,
#     'trophies': 1600,
#     'arena': {'id': 54000006, 'name': "P.E.K.K.A's Playhouse"},
#     'clanRank': 49,
#     'previousClanRank': 49,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0}]},
#  '#RPQ2QGYC': {'tag': '#RPQ2QGYC',
#   'name': 'ONE PIECE',
#   'type': 'open',
#   'description': 'ONE PIECE İZLEYİN İZLETTİRİN!!! Klan savaşları zorunludur!!! Savaşları yapmayan ve aktif olmayan oyuncular atılır.',
#   'badgeId': 16000024,
#   'clanScore': 76289,
#   'clanWarTrophies': 510,
#   'location': {'id': 57000239,
#    'name': 'Turkey',
#    'isCountry': True,
#    'countryCode': 'TR'},
#   'requiredTrophies': 6500,
#   'donationsPerWeek': 2720,
#   'clanChestStatus': 'inactive',
#   'clanChestLevel': 1,
#   'clanChestMaxLevel': 0,
#   'members': 41,
#   'memberList': [{'tag': '#Y08V0CPLR',
#     'name': 'allah',
#     'role': 'coLeader',
#     'lastSeen': '20250529T055837.000Z',
#     'expLevel': 57,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 1,
#     'previousClanRank': 2,
#     'donations': 250,
#     'donationsReceived': 210,
#     'clanChestPoints': 0},
#    {'tag': '#QQQ9LY902',
#     'name': 'rA9',
#     'role': 'leader',
#     'lastSeen': '20250528T205007.000Z',
#     'expLevel': 62,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 2,
#     'previousClanRank': 1,
#     'donations': 184,
#     'donationsReceived': 200,
#     'clanChestPoints': 0},
#    {'tag': '#80LQCG9UC',
#     'name': 'JrNathing...',
#     'role': 'elder',
#     'lastSeen': '20250528T121228.000Z',
#     'expLevel': 55,
#     'trophies': 9000,
#     'arena': {'id': 54000020, 'name': 'Valkalla'},
#     'clanRank': 3,
#     'previousClanRank': 3,
#     'donations': 78,
#     'donationsReceived': 120,
#     'clanChestPoints': 0},
#    {'tag': '#U992YVRQY',
#     'name': 'Amoreh',
#     'role': 'elder',
#     'lastSeen': '20250528T223608.000Z',
#     'expLevel': 49,
#     'trophies': 8352,
#     'arena': {'id': 54000018, 'name': 'Clash Fest'},
#     'clanRank': 4,
#     'previousClanRank': 4,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#8RQR9R0Y0',
#     'name': 'THE W',
#     'role': 'elder',
#     'lastSeen': '20250529T002642.000Z',
#     'expLevel': 47,
#     'trophies': 8167,
#     'arena': {'id': 54000018, 'name': 'Clash Fest'},
#     'clanRank': 5,
#     'previousClanRank': 5,
#     'donations': 0,
#     'donationsReceived': 40,
#     'clanChestPoints': 0},
#    {'tag': '#YC0YJVVLJ',
#     'name': 'emre yt',
#     'role': 'elder',
#     'lastSeen': '20250528T170026.000Z',
#     'expLevel': 42,
#     'trophies': 8139,
#     'arena': {'id': 54000018, 'name': 'Clash Fest'},
#     'clanRank': 6,
#     'previousClanRank': 6,
#     'donations': 12,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#8PJCVQ8CR',
#     'name': 'SROMERO',
#     'role': 'elder',
#     'lastSeen': '20250529T055431.000Z',
#     'expLevel': 43,
#     'trophies': 8005,
#     'arena': {'id': 54000018, 'name': 'Clash Fest'},
#     'clanRank': 7,
#     'previousClanRank': 7,
#     'donations': 162,
#     'donationsReceived': 179,
#     'clanChestPoints': 0},
#    {'tag': '#GUQQ80P8P',
#     'name': 'bluewin',
#     'role': 'coLeader',
#     'lastSeen': '20250528T183215.000Z',
#     'expLevel': 51,
#     'trophies': 8003,
#     'arena': {'id': 54000018, 'name': 'Clash Fest'},
#     'clanRank': 8,
#     'previousClanRank': 8,
#     'donations': 122,
#     'donationsReceived': 40,
#     'clanChestPoints': 0},
#    {'tag': '#UJ8GC8VR9',
#     'name': 'cansnow',
#     'role': 'elder',
#     'lastSeen': '20250528T195935.000Z',
#     'expLevel': 47,
#     'trophies': 8000,
#     'arena': {'id': 54000018, 'name': 'Clash Fest'},
#     'clanRank': 9,
#     'previousClanRank': 9,
#     'donations': 127,
#     'donationsReceived': 200,
#     'clanChestPoints': 0},
#    {'tag': '#28JQJLQY0',
#     'name': 'SmallCat',
#     'role': 'elder',
#     'lastSeen': '20250528T032647.000Z',
#     'expLevel': 44,
#     'trophies': 8000,
#     'arena': {'id': 54000018, 'name': 'Clash Fest'},
#     'clanRank': 10,
#     'previousClanRank': 10,
#     'donations': 44,
#     'donationsReceived': 160,
#     'clanChestPoints': 0},
#    {'tag': '#VP28RLU22',
#     'name': 'Nrv2100',
#     'role': 'elder',
#     'lastSeen': '20250527T061709.000Z',
#     'expLevel': 42,
#     'trophies': 7819,
#     'arena': {'id': 54000017, 'name': 'Boot Camp'},
#     'clanRank': 11,
#     'previousClanRank': 12,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#8U02PVL8L',
#     'name': 'EGOISTA',
#     'role': 'elder',
#     'lastSeen': '20250528T225337.000Z',
#     'expLevel': 45,
#     'trophies': 7810,
#     'arena': {'id': 54000017, 'name': 'Boot Camp'},
#     'clanRank': 12,
#     'previousClanRank': 11,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#RJ0YR2C0',
#     'name': 'batukaan efendi',
#     'role': 'elder',
#     'lastSeen': '20250529T060417.000Z',
#     'expLevel': 48,
#     'trophies': 7802,
#     'arena': {'id': 54000017, 'name': 'Boot Camp'},
#     'clanRank': 13,
#     'previousClanRank': 13,
#     'donations': 46,
#     'donationsReceived': 88,
#     'clanChestPoints': 0},
#    {'tag': '#G8UGLQPJQ',
#     'name': '~S E G M E N~',
#     'role': 'coLeader',
#     'lastSeen': '20250528T191642.000Z',
#     'expLevel': 46,
#     'trophies': 7738,
#     'arena': {'id': 54000017, 'name': 'Boot Camp'},
#     'clanRank': 14,
#     'previousClanRank': 14,
#     'donations': 60,
#     'donationsReceived': 160,
#     'clanChestPoints': 0},
#    {'tag': '#92CQ2RYLC',
#     'name': 'Relettin',
#     'role': 'elder',
#     'lastSeen': '20250528T223447.000Z',
#     'expLevel': 44,
#     'trophies': 7625,
#     'arena': {'id': 54000017, 'name': 'Boot Camp'},
#     'clanRank': 15,
#     'previousClanRank': 16,
#     'donations': 16,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#VVLVP0ULC',
#     'name': 'Redx',
#     'role': 'elder',
#     'lastSeen': '20250526T183741.000Z',
#     'expLevel': 40,
#     'trophies': 7500,
#     'arena': {'id': 54000017, 'name': 'Boot Camp'},
#     'clanRank': 16,
#     'previousClanRank': 17,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#8CG8G99J',
#     'name': 'Bay Yeşil',
#     'role': 'elder',
#     'lastSeen': '20250528T210724.000Z',
#     'expLevel': 40,
#     'trophies': 7440,
#     'arena': {'id': 54000016, 'name': 'Dragon Spa'},
#     'clanRank': 17,
#     'previousClanRank': 19,
#     'donations': 18,
#     'donationsReceived': 40,
#     'clanChestPoints': 0},
#    {'tag': '#UL0UG2PL2',
#     'name': 'cris',
#     'role': 'elder',
#     'lastSeen': '20250520T012052.000Z',
#     'expLevel': 34,
#     'trophies': 7432,
#     'arena': {'id': 54000016, 'name': 'Dragon Spa'},
#     'clanRank': 18,
#     'previousClanRank': 18,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#PUYVY292Y',
#     'name': 'yaģız',
#     'role': 'elder',
#     'lastSeen': '20250528T155930.000Z',
#     'expLevel': 44,
#     'trophies': 7376,
#     'arena': {'id': 54000016, 'name': 'Dragon Spa'},
#     'clanRank': 19,
#     'previousClanRank': 20,
#     'donations': 208,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#YYVL0YP',
#     'name': 'A.J.',
#     'role': 'elder',
#     'lastSeen': '20250523T212251.000Z',
#     'expLevel': 38,
#     'trophies': 7273,
#     'arena': {'id': 54000016, 'name': 'Dragon Spa'},
#     'clanRank': 20,
#     'previousClanRank': 21,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#YLG0LURPG',
#     'name': 'Entoxx',
#     'role': 'elder',
#     'lastSeen': '20250528T235926.000Z',
#     'expLevel': 47,
#     'trophies': 7268,
#     'arena': {'id': 54000016, 'name': 'Dragon Spa'},
#     'clanRank': 21,
#     'previousClanRank': 22,
#     'donations': 48,
#     'donationsReceived': 40,
#     'clanChestPoints': 0},
#    {'tag': '#LP2PR2Y92',
#     'name': '(+_+) MUHAMMED™',
#     'role': 'elder',
#     'lastSeen': '20250525T210602.000Z',
#     'expLevel': 39,
#     'trophies': 7245,
#     'arena': {'id': 54000016, 'name': 'Dragon Spa'},
#     'clanRank': 22,
#     'previousClanRank': 23,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#C0928PQ8C',
#     'name': 'KRAL RECEP',
#     'role': 'elder',
#     'lastSeen': '20250527T134513.000Z',
#     'expLevel': 39,
#     'trophies': 7189,
#     'arena': {'id': 54000016, 'name': 'Dragon Spa'},
#     'clanRank': 23,
#     'previousClanRank': 24,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#JPR2LG8YC',
#     'name': 'Shinsui',
#     'role': 'elder',
#     'lastSeen': '20250529T050342.000Z',
#     'expLevel': 39,
#     'trophies': 7155,
#     'arena': {'id': 54000016, 'name': 'Dragon Spa'},
#     'clanRank': 24,
#     'previousClanRank': 25,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#Q0LP2LVUV',
#     'name': 'pirata',
#     'role': 'elder',
#     'lastSeen': '20250529T005839.000Z',
#     'expLevel': 40,
#     'trophies': 7143,
#     'arena': {'id': 54000016, 'name': 'Dragon Spa'},
#     'clanRank': 25,
#     'previousClanRank': 30,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#YRV2LQ9UQ',
#     'name': 'Adal_G',
#     'role': 'elder',
#     'lastSeen': '20250528T233806.000Z',
#     'expLevel': 38,
#     'trophies': 7127,
#     'arena': {'id': 54000016, 'name': 'Dragon Spa'},
#     'clanRank': 26,
#     'previousClanRank': 26,
#     'donations': 259,
#     'donationsReceived': 280,
#     'clanChestPoints': 0},
#    {'tag': '#LPVC8Y999',
#     'name': 'WhITEBEArD',
#     'role': 'elder',
#     'lastSeen': '20250529T053034.000Z',
#     'expLevel': 37,
#     'trophies': 7096,
#     'arena': {'id': 54000016, 'name': 'Dragon Spa'},
#     'clanRank': 27,
#     'previousClanRank': 27,
#     'donations': 30,
#     'donationsReceived': 70,
#     'clanChestPoints': 0},
#    {'tag': '#J8QG0QU8J',
#     'name': 'MAGA',
#     'role': 'elder',
#     'lastSeen': '20250528T214010.000Z',
#     'expLevel': 37,
#     'trophies': 7069,
#     'arena': {'id': 54000016, 'name': 'Dragon Spa'},
#     'clanRank': 28,
#     'previousClanRank': 28,
#     'donations': 0,
#     'donationsReceived': 80,
#     'clanChestPoints': 0},
#    {'tag': '#VC8L89QYL',
#     'name': 'Jens D Sitta',
#     'role': 'elder',
#     'lastSeen': '20250528T121828.000Z',
#     'expLevel': 41,
#     'trophies': 7069,
#     'arena': {'id': 54000016, 'name': 'Dragon Spa'},
#     'clanRank': 29,
#     'previousClanRank': 31,
#     'donations': 194,
#     'donationsReceived': 200,
#     'clanChestPoints': 0},
#    {'tag': '#Y29QL00PC',
#     'name': 'maxiking',
#     'role': 'elder',
#     'lastSeen': '20250528T230906.000Z',
#     'expLevel': 38,
#     'trophies': 7037,
#     'arena': {'id': 54000016, 'name': 'Dragon Spa'},
#     'clanRank': 30,
#     'previousClanRank': 34,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#QUPYGGGG2',
#     'name': 'LEK7ZIN',
#     'role': 'elder',
#     'lastSeen': '20250528T182930.000Z',
#     'expLevel': 50,
#     'trophies': 7030,
#     'arena': {'id': 54000016, 'name': 'Dragon Spa'},
#     'clanRank': 31,
#     'previousClanRank': 32,
#     'donations': 18,
#     'donationsReceived': 80,
#     'clanChestPoints': 0},
#    {'tag': '#V0LV82JVG',
#     'name': 'YAA KRALLIĞI',
#     'role': 'elder',
#     'lastSeen': '20250528T101713.000Z',
#     'expLevel': 37,
#     'trophies': 7028,
#     'arena': {'id': 54000016, 'name': 'Dragon Spa'},
#     'clanRank': 32,
#     'previousClanRank': 33,
#     'donations': 0,
#     'donationsReceived': 40,
#     'clanChestPoints': 0},
#    {'tag': '#UVQQQ00YP',
#     'name': 'Shanks',
#     'role': 'elder',
#     'lastSeen': '20250528T194009.000Z',
#     'expLevel': 40,
#     'trophies': 6929,
#     'arena': {'id': 54000015, 'name': 'Silent Sanctuary'},
#     'clanRank': 33,
#     'previousClanRank': 35,
#     'donations': 42,
#     'donationsReceived': 40,
#     'clanChestPoints': 0},
#    {'tag': '#8CLG9YJ8',
#     'name': 'Arda',
#     'role': 'elder',
#     'lastSeen': '20250528T221859.000Z',
#     'expLevel': 36,
#     'trophies': 6824,
#     'arena': {'id': 54000015, 'name': 'Silent Sanctuary'},
#     'clanRank': 34,
#     'previousClanRank': 37,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#GC8QUURCP',
#     'name': 'rt.Phantom',
#     'role': 'elder',
#     'lastSeen': '20250528T223010.000Z',
#     'expLevel': 40,
#     'trophies': 6792,
#     'arena': {'id': 54000015, 'name': 'Silent Sanctuary'},
#     'clanRank': 35,
#     'previousClanRank': 38,
#     'donations': 16,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#Y9R8Q9JL',
#     'name': 'Dmarcus Cousins',
#     'role': 'elder',
#     'lastSeen': '20250529T011022.000Z',
#     'expLevel': 41,
#     'trophies': 6784,
#     'arena': {'id': 54000015, 'name': 'Silent Sanctuary'},
#     'clanRank': 36,
#     'previousClanRank': 39,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#CG9Y8QY28',
#     'name': '温馨敬 語Łykroz',
#     'role': 'elder',
#     'lastSeen': '20250528T221400.000Z',
#     'expLevel': 40,
#     'trophies': 6737,
#     'arena': {'id': 54000015, 'name': 'Silent Sanctuary'},
#     'clanRank': 37,
#     'previousClanRank': 40,
#     'donations': 116,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#JYC2R8JQJ',
#     'name': 'M1903',
#     'role': 'elder',
#     'lastSeen': '20250529T053925.000Z',
#     'expLevel': 40,
#     'trophies': 6664,
#     'arena': {'id': 54000015, 'name': 'Silent Sanctuary'},
#     'clanRank': 38,
#     'previousClanRank': 41,
#     'donations': 26,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#Q8YLQJ2PP',
#     'name': 'NOBBİE',
#     'role': 'elder',
#     'lastSeen': '20250525T074444.000Z',
#     'expLevel': 40,
#     'trophies': 6619,
#     'arena': {'id': 54000015, 'name': 'Silent Sanctuary'},
#     'clanRank': 39,
#     'previousClanRank': 42,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0},
#    {'tag': '#YPRJQQULJ',
#     'name': '+baranbaba+',
#     'role': 'elder',
#     'lastSeen': '20250529T055127.000Z',
#     'expLevel': 38,
#     'trophies': 6500,
#     'arena': {'id': 54000015, 'name': 'Silent Sanctuary'},
#     'clanRank': 40,
#     'previousClanRank': 43,
#     'donations': 60,
#     'donationsReceived': 40,
#     'clanChestPoints': 0},
#    {'tag': '#CYUVR9RJR',
#     'name': 'E.D.I.T.H',
#     'role': 'elder',
#     'lastSeen': '20250525T192821.000Z',
#     'expLevel': 40,
#     'trophies': 5266,
#     'arena': {'id': 54000012, 'name': "Miner's Mine"},
#     'clanRank': 41,
#     'previousClanRank': 44,
#     'donations': 0,
#     'donationsReceived': 0,
#     'clanChestPoints': 0}]}}

# %%
# 1. Cargar el archivo correctamente
with open('clanes_data.json', 'r') as f:
    clan_data = json.load(f)  # clan_data es ahora un diccionario

# 2. Convertir a DataFrame (estructura deseada)
df = (
    pd.DataFrame.from_dict(clan_data, orient='index')
    .reset_index()
    .rename(columns={'index': 'tag'})
)

# 3. Si hay datos anidados (ej: "location": {"country": "Chile"}):
df_final = pd.json_normalize(
    df.to_dict('memberList'),  # Datos a normalizar
    sep='_',
    max_level= 3                # Separador para campos anidados
)

# Mostrar resultado
df_final.head(5)
# Out:
# /tmp/ipykernel_5964/4285346352.py:14: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   df.to_dict('memberList'),  # Datos a normalizar
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 14
#       6 df = (
#       7     pd.DataFrame.from_dict(clan_data, orient='index')
#       8     .reset_index()
#       9     .rename(columns={'index': 'tag'})
#      10 )
#      12 # 3. Si hay datos anidados (ej: "location": {"country": "Chile"}):
#      13 df_final = pd.json_normalize(
# ---> 14     df.to_dict('memberList'),  # Datos a normalizar
#      15     sep='_',
#      16     max_level= 3                # Separador para campos anidados
#      17 )
#      19 # Mostrar resultado
#      20 df_final.head(5)
#
# File ~/.local/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:2178, in DataFrame.to_dict(self, orient, into, index)
#    2075 """
#    2076 Convert the DataFrame to a dictionary.
#    2077
#    (...)   2174  defaultdict(<class 'list'>, {'col1': 2, 'col2': 0.75})]
#    2175 """
#    2176 from pandas.core.methods.to_dict import to_dict
# -> 2178 return to_dict(self, orient, into=into, index=index)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/methods/to_dict.py:272, in to_dict(df, orient, into, index)
#     267         return into_c(
#     268             (t[0], dict(zip(df.columns, t[1:]))) for t in df.itertuples(name=None)
#     269         )
#     271 else:
# --> 272     raise ValueError(f"orient '{orient}' not understood")
#
# ValueError: orient 'memberlist' not understood

# %%
df_final = json_normalize(df_transformed.to_dict('records'))

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   tag_clan              7 non-null      object
#  1   tag                   7 non-null      object
#  2   name                  7 non-null      object
#  3   type                  7 non-null      object
#  4   description           7 non-null      object
#  5   badgeId               7 non-null      int64
#  6   clanScore             7 non-null      int64
#  7   clanWarTrophies       7 non-null      int64
#  8   requiredTrophies      7 non-null      int64
#  9   donationsPerWeek      7 non-null      int64
#  10  clanChestStatus       7 non-null      object
#  11  clanChestLevel        7 non-null      int64
#  12  clanChestMaxLevel     7 non-null      int64
#  13  members               7 non-null      int64
#  14  memberList            7 non-null      object
#  15  location.id           7 non-null      int64
#  16  location.name         7 non-null      object
#  17  location.isCountry    7 non-null      bool
#  18  location.countryCode  6 non-null      object
# dtypes: bool(1), int64(9), object(9)
# memory usage: 1.1+ KB

# %%
df = pd.read_json('clanes_data.json')

# %%
#transformando el dataframe
df_transformed = df.reset_index().rename(columns={'index': 'tag_clan'})
#normalizando columnas
df_final = json_normalize(df_transformed.to_dict('records'))

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   tag_clan              7 non-null      object
#  1   tag                   7 non-null      object
#  2   name                  7 non-null      object
#  3   type                  7 non-null      object
#  4   description           7 non-null      object
#  5   badgeId               7 non-null      int64
#  6   clanScore             7 non-null      int64
#  7   clanWarTrophies       7 non-null      int64
#  8   requiredTrophies      7 non-null      int64
#  9   donationsPerWeek      7 non-null      int64
#  10  clanChestStatus       7 non-null      object
#  11  clanChestLevel        7 non-null      int64
#  12  clanChestMaxLevel     7 non-null      int64
#  13  members               7 non-null      int64
#  14  memberList            7 non-null      object
#  15  location.id           7 non-null      int64
#  16  location.name         7 non-null      object
#  17  location.isCountry    7 non-null      bool
#  18  location.countryCode  6 non-null      object
# dtypes: bool(1), int64(9), object(9)
# memory usage: 1.1+ KB

# %%
df_final.sample(5)
# Out:
#     tag_clan        tag             name        type  \
# 1  #GG0C0VR0  #GG0C0VR0     Jynxzi Verse  inviteOnly
# 3  #LC0GJGRV  #LC0GJGRV  los mercenarios  inviteOnly
# 5    #9JUP2U    #9JUP2U        HOLLIGANS        open
# 4  #YVQV2VVY  #YVQV2VVY         BAD BOYS  inviteOnly
# 6  #RPQ2QGYC  #RPQ2QGYC        ONE PIECE        open
#
#                                          description   badgeId  clanScore  \
# 1                                                     16000008      90000
# 3  Se regalan 3 pass a los 3 top guerra. 2,200 pt...  16000077      90000
# 5  clan de chill pero con ganas de competir / obl...  16000029      79510
# 4  ♨️CLAN COMPETITIVO♨️ATACAR EN GUERRA 4/4 ATAQU...  16000009      90000
# 6  ONE PIECE İZLEYİN İZLETTİRİN!!! Klan savaşları...  16000024      76289
#
#    clanWarTrophies  requiredTrophies  donationsPerWeek clanChestStatus  \
# 1              180              9000              3944        inactive
# 3             4922              9000              3815        inactive
# 5             1833              1300              1802        inactive
# 4             3693              9000              4148        inactive
# 6              510              6500              2720        inactive
#
#    clanChestLevel  clanChestMaxLevel  members  \
# 1               1                  0       50
# 3               1                  0       50
# 5               1                  0       49
# 4               1                  0       50
# 6               1                  0       41
#
#                                           memberList  location.id  \
# 1  [{'tag': '#YJPLQRR09', 'name': 'Lil Log', 'rol...     57000006
# 3  [{'tag': '#9PGU890Q9', 'name': 'MikeXGamer™', ...     57000169
# 5  [{'tag': '#29809G2LL', 'name': 'fernand0', 'ro...     57000153
# 4  [{'tag': '#JQ82089QR', 'name': 'xoguh12', 'rol...     57000153
# 6  [{'tag': '#Y08V0CPLR', 'name': 'allah', 'role'...     57000239
#
#    location.name  location.isCountry location.countryCode
# 1  International               False                  NaN
# 3      Nicaragua                True                   NI
# 5         Mexico                True                   MX
# 4         Mexico                True                   MX
# 6         Turkey                True                   TR

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   tag_clan              7 non-null      object
#  1   tag                   7 non-null      object
#  2   name                  7 non-null      object
#  3   type                  7 non-null      object
#  4   description           7 non-null      object
#  5   badgeId               7 non-null      int64
#  6   clanScore             7 non-null      int64
#  7   clanWarTrophies       7 non-null      int64
#  8   requiredTrophies      7 non-null      int64
#  9   donationsPerWeek      7 non-null      int64
#  10  clanChestStatus       7 non-null      object
#  11  clanChestLevel        7 non-null      int64
#  12  clanChestMaxLevel     7 non-null      int64
#  13  members               7 non-null      int64
#  14  memberList            7 non-null      object
#  15  location.id           7 non-null      int64
#  16  location.name         7 non-null      object
#  17  location.isCountry    7 non-null      bool
#  18  location.countryCode  6 non-null      object
# dtypes: bool(1), int64(9), object(9)
# memory usage: 1.1+ KB
